# %% [markdown]
# <a href="https://colab.research.google.com/github/Mickey5480/Data110-Fall2025/blob/main/Week2_in_class_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# lets add some libraries

# %%
# matplot is for data vizulization
import matplotlib.pyplot as plt
# to work with array, numerical calculation
import numpy as np
# for dataframe
import pandas as pd

# %% [markdown]
# Now, we need to add dataset... first add to here.. upload to google colab (not my fav)

# %%
DF=pd.read_csv('/content/happiness.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1120291100.py in <cell line: 0>()
# ----> 1 DF=pd.read_csv('/content/happiness.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %% [markdown]
# or a better, use our friend (github)

# %%
ds=pd.read_csv('https://raw.githubusercontent.com/Mickey5480/Data110-21843--fall25/refs/heads/main/dataset/happiness.csv')

# %%
ds.head()
# Out:
#        country  Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# 0      Denmark     1            7.693     7.519909           10.699571
# 1       Norway     2            7.655     7.678277           11.050944
# 2  Switzerland     3            7.650     7.776209           10.935776
# 3  Netherlands     4            7.512     7.470716           10.723517
# 4       Sweden     5            7.480     7.560148           10.676098
#
#    Social support  Healthy life expectancy at birth  \
# 0        0.951437                         70.044815
# 1        0.947657                         70.524834
# 2        0.946864                         72.734001
# 3        0.938885                         71.091934
# 4        0.929397                         71.740868
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.932628    0.127539                   0.187408
# 1                      0.946566    0.120922                   0.368043
# ...

# %%
ds.head(10)
# Out:
#        country  Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# 0      Denmark     1            7.693     7.519909           10.699571
# 1       Norway     2            7.655     7.678277           11.050944
# 2  Switzerland     3            7.650     7.776209           10.935776
# 3  Netherlands     4            7.512     7.470716           10.723517
# 4       Sweden     5            7.480     7.560148           10.676098
# 5       Canada     6            7.477     7.415144           10.640521
# 6      Finland     7            7.389     7.420209           10.594456
# 7      Austria     8            7.369     7.400689           10.705052
# 8      Iceland     9            7.355     7.590660           10.589972
# 9    Australia    10            7.350     7.195586           10.658696
#
#    Social support  Healthy life expectancy at birth  \
# 0        0.951437                         70.044815
# 1        0.947657                         70.524834
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 20 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   country                                                   142 non-null    object
#  1   Rank                                                      142 non-null    int64
#  2   Happiness Score                                           142 non-null    float64
#  3   Life Ladder                                               142 non-null    float64
#  4   Log GDP per capita                                        139 non-null    float64
#  5   Social support                                            142 non-null    float64
#  6   Healthy life expectancy at birth                          140 non-null    float64
#  7   Freedom to make life choices                              141 non-null    float64
# ...

# %%
ds.describe()
# Out:
#              Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# count  142.000000       142.000000   142.000000          139.000000
# mean    71.500000         5.467239     5.443751            9.277067
# std     41.135953         1.087999     1.116592            1.149919
# min      1.000000         3.528000     3.164491            6.481236
# 25%     36.250000         4.613750     4.603896            8.409574
# 50%     71.500000         5.346500     5.336502            9.419761
# 75%    106.750000         6.284750     6.210948           10.156146
# max    142.000000         7.693000     7.776209           11.738482
#
#        Social support  Healthy life expectancy at birth  \
# count      142.000000                        140.000000
# mean         0.809077                         62.710796
# std          0.112769                          7.338667
# min          0.510575                         44.032639
# 25%          0.743069                         57.917182
# ...

# %% [markdown]
# 'plt.scatter(x_data,x_data)'

# %%
plt.scatter(ds['Rank'],ds['Happiness Score'])

# %%
plt.figure(figsize=(10,5))
plt.scatter(ds['Rank'],ds['Happiness Score'])

# %%
plt.figure(figsize=(10,5))
plt.scatter(ds['Rank'],ds['Happiness Score'])
plt.xlabel('Rank')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Rank')
# Out:
# Text(0.5, 1.0, 'Happiness Score vs Rank')

# %%
plt.figure(figsize=(10,5))
plt.scatter(ds['Rank'],ds['Happiness Score'],color='blue',marker='+' ,alpha=0.1)
plt.xlabel('Rank')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Rank')
# Out:
# Text(0.5, 1.0, 'Happiness Score vs Rank')

# %%
plt.figure(figsize=(10,5))
plt.scatter(ds['Rank'],ds['Happiness Score'],color='blue',alpha=1)
plt.xlabel('Rank')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Rank')
plt.grid(True)

# %%
m,b=np.polyfit(x,y1,1) # m is slope while b is y-intercept
reg_line=m+np.array(x)+b
plt.plot(x,reg_line,color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1313818446.py in <cell line: 0>()
# ----> 1 m,b=np.polyfit(x,y1,1) # m is slope while b is y-intercept
#       2 reg_line=m+np.array(x)+b
#       3 plt.plot(x,reg_line,color='red')
#
# NameError: name 'x' is not defined
