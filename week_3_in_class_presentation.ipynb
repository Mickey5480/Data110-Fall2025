# %% [markdown]
# <a href="https://colab.research.google.com/github/Mickey5480/Data110-Fall2025/blob/main/week_3_in_class_presentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# linespace(a,b,n)
# what is the $\frac{b-a}{n-1}$
#
# note, in python to write Sx^2

# %%
x=np.linspace(0,10,100)
y=x**2
plt.plot(x,y)

# %%
x=np.linspace(0,10,100)
z=np.sin(x)
plt.plot(x,z)

# %%
x=np.linspace(0,10,100)
z=np.sin(x)
w=np.cos(x)
plt.plot(x,z)
plt.plot(x,w)

# %%
plt.plot(x,x+1,linestyle='solid',linewidth=3)
plt.plot(x,x+2,linestyle='dashed',linewidth=5)
plt.plot(x,x+3,linestyle='dashdot')

# %%
plt.plot(x,np.sin(x),label='sin(x)')
plt.plot(x,np.cos(x),label='cos(x)')
plt.legend(loc='upper right')
plt.show()

# %%
plt.scatter(x,y,color='black',label='sin(x)')
plt.legend(loc='lower right')
plt.show()

# %%
plt.scatter(x,y,
plt.legend(loc='lower right')
plt.show()
# Out:
#   File "/tmp/ipython-input-585451277.py", line 2
#     plt.scatter(x,z,color='red',label='cos(x)
#                                       ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
plt.plot(x,y,'-p',color='red')
plt.ylim(0,1)
# Out:
# (0.0, 1.0)
